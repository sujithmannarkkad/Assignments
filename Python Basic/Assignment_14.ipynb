# %%
1. What does RGBA stand for?

What does RGB and RGBA stand for?
RGB is a 3-channel format containing data for Red, Green, and Blue. 
RGBA is a 4-channel format containing data for Red, Green, Blue, and Alpha. 
There is no use to the Alpha channel other than making the color transparent/opaque (or partially transparent; translucent).

# %%
2. From the Pillow module, how do you get the RGBA value of any images?

getpixel() witll give you (red, green, blue, alpha) tuples.

from PIL import Image
imgobj = Image.open('profile pic.jpg')
pixels = imgobj.convert('RGBA')
lofpixels = []
w = 1920
h = 1080
for i in range(w):
    for j in range(h):
        r,g,b,a = pixels.getpixel((i,j))
        print(r,g,b,a)

# %%
3. What is a box tuple, and how does it work?

Many of Pillow’s functions and methods take a box tuple argument. This means Pillow is expecting a tuple of four integer coordinates that represent a rectangular region in an image. The four integers are, in order, as follows:

Left The x-coordinate of the leftmost edge of the box.

Top The y-coordinate of the top edge of the box.

Right The x-coordinate of one pixel to the right of the rightmost edge of the box. This integer must be greater than the left integer.

Bottom The y-coordinate of one pixel lower than the bottom edge of the box. This integer must be greater than the top integer.

# %%
4. Use your image and load in notebook then, How can you find out the width and height of an Image object?

# %%
from PIL import Image
im=Image.open('flower.jpg')
display(im)
im.height, im.width
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x1E484F512B0>
# (168, 300)

# %%
5. What method would you call to get Image object for a 100×100 image, excluding the lower-left quarter of it?

we can use im.crop() function, Set the cropping area with box=(left, upper, right, lower)

# %%
6. After making changes to an Image object, how could you save it as an image file?

we can use save function to save the new file.

from PIL import Image
image = Image.open('flower.jpg')
new_image = image.resize((400, 400))
new_image.save('flower_400.jpg')

print(image.size) # Output: (1920, 1280)
print(new_image.size) # Output: (400, 400)
# Out:
# (300, 168)
# (400, 400)

# %%
7. What module contains Pillow’s shape-drawing code?

ImageDraw module of the Python image processing library Pillow (PIL) provides a number of methods for drawing figures such as circle, square, and straight line.

# %%
8. Image objects do not have drawing methods. What kind of object does? How do you get this kind of object?


If you need to draw lines, rectangles, circles, or other simple shapes on an image, use Pillow’s ImageDraw module

from PIL import Image, ImageDraw
im = Image.new('RGBA', (200, 200), 'white')
draw = ImageDraw.Draw(im)
First, we import Image and ImageDraw. Then we create a new image, in this case, a 200×200 white image, 
and store the Image object in im. 
We pass the Image object to the ImageDraw.Draw() function to receive an ImageDraw object. 
This object has several methods for drawing shapes and text onto an Image object. 
Store the ImageDraw object in a variable like draw so you can use it easily in the following example.

draw.line([(0, 0), (199, 0), (199, 199), (0, 199), (0, 0)], fill='black')
draw.rectangle((20, 30, 60, 60), fill='blue')
im.save('drawing.png')

# %%
from PIL import Image, ImageDraw
im = Image.new('RGBA', (200, 200), 'white')
draw = ImageDraw.Draw(im)


draw.line([(0, 0), (199, 0), (199, 199), (0, 199), (0, 0)], fill='black')
draw.rectangle((20, 30, 60, 60), fill='blue')
#im.save('drawing.png')
draw.ellipse((120, 30, 160, 60), fill='red')
draw.polygon(((57, 87), (79, 62), (94, 85), (120, 90), (103, 113)),
   fill='brown')
for i in range(100, 200, 10):
           draw.line([(i, 0), (200, i - 100)], fill='green')
display(im)
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x1E4C65A7190>
